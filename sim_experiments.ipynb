# %% [markdown]
# # Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython import display

import numpy as np
import pandas as pd

from word2vec_as_EMF import word2vec_as_EMF
from functions import *

# %% [markdown]
# # Load models

# %%
model_imdb = word2vec_as_EMF()
model_imdb.load_matrices(from_file='imdb-200_matrices.npz')

model_enwik = word2vec_as_EMF()
model_enwik.load_matrices(from_file='enwik-1000_matrices.npz')

# %% [markdown]
# # Wordsim353 experiments

# %%
dataset = pd.read_csv("data/wordsim353/combined.csv")

# %% [markdown]
# ### IMDB (Projector splitting)

# %%
from_folder = 'imdb-200_PS500iter_fromSVD_factors'
MAX_ITER = 500

# %%
wi_corrs, wi_vecs, wi_vec2 = corr_experiment(model_imdb, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
plot_dynamics(wi_vecs, wi_vec2, 10, MAX_ITER=MAX_ITER)

# %% [markdown]
# ### Enwik (Projector splitting)

# %%
from_folder = 'enwik-1000_PS400iter_fromSVD_factors'
MAX_ITER = 400

# %%
wpse_corrs, wpse_vecs, wpse_vec2 = corr_experiment(model_enwik, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
plot_dynamics(wpse_vecs, wpse_vec2, 5, MAX_ITER=MAX_ITER)

# %% [markdown]
# ### Enwik (Alternating minimization)

# %%
from_folder = 'enwik-1000_AM999iter_fromSVD_factors'
MAX_ITER = 999

# %%
wame_corrs, wame_vecs, wame_vec2 = corr_experiment(model_enwik, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
plot_dynamics(wame_vecs, wame_vec2, 40, MAX_ITER=MAX_ITER)

# %% [markdown]
# # MEN experiments

# %%
dataset = pd.read_csv("data/MEN/MEN_dataset_natural_form_full", header=None, delimiter=' ')

# %% [markdown]
# ### IMDB (Projector splitting)

# %%
from_folder = 'imdb-200_PS500iter_fromSVD_factors'
MAX_ITER = 500

# %%
mi_corrs, mi_vecs, mi_vec2 = corr_experiment(model_imdb, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
plot_dynamics(mi_vecs, mi_vec2, 10, MAX_ITER=MAX_ITER)

# %% [markdown]
# ### Enwik (Projector splitting)

# %%
from_folder = 'enwik-1000_PS400iter_fromSVD_factors'
MAX_ITER = 400

# %%
mpse_corrs, mpse_vecs, mpse_vec2 = corr_experiment(model_enwik, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
plot_dynamics(mpse_vecs, mpse_vec2, 10, MAX_ITER=MAX_ITER)

# %% [markdown]
# ### Enwik (Alternating minimization)

# %%
from_folder = 'enwik-1000_AM999iter_fromSVD_factors'
MAX_ITER = 999

# %%
mame_corrs, mame_vecs, mame_vec2 = corr_experiment(model_enwik, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
plot_dynamics(mame_vecs, mame_vec2, 20, MAX_ITER=MAX_ITER)

# %% [markdown]
# # Objective optimization

# %%
MF_imdb = model_imdb.load_MF('imdb-200_PS500iter_fromSVD_MF.npz')
plot_MF(MF_imdb)

# %%
MF_enwik_PS = model_enwik.load_MF('enwik-1000_PS400iter_fromSVD_MF.npz')
plot_MF(MF_enwik_PS)

# %%
MF_enwik_AM = model_enwik.load_MF('enwik-1000_AM999iter_fromSVD_MF.npz')
plot_MF(MF_enwik_AM)

# %%
model_enwik = word2vec_as_EMF()
model_enwik.load_matrices(from_file='enwik-200_matrices.npz')

# %%
#dataset = pd.read_csv("data/wordsim353/combined.csv")
dataset = pd.read_csv("data/MEN/MEN_dataset_natural_form_full", header=None, delimiter=' ')
#from_folder = 'temp'
from_folder='temp2'
MAX_ITER = 1

# %%
corrs, vecs, vec2 = corr_experiment(model_enwik, dataset, from_folder, 
                                    MAX_ITER=MAX_ITER, plot_corrs=True)

# %%
corrs
# Out:
# array([-0.73613689])

# %%
C, W = model_enwik.load_CW(from_folder='temp', iteration=0)
